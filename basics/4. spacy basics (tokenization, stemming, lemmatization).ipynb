# %%
# !pip install nltk, spacy

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("Elon Musk can pocket another $32 billion of Tesla shares")
print(doc, '\n')

for token in doc: 
    print(token.text,"::", token.pos_,"::", token.dep_)
# Out:
# Elon Musk can pocket another $32 billion of Tesla shares
#
# Elon :: PROPN :: compound
# Musk :: PROPN :: nsubj
# can :: AUX :: aux
# pocket :: VERB :: ROOT
# another :: DET :: det
# $ :: SYM :: quantmod
# 32 :: NUM :: compound
# billion :: NUM :: dobj
# of :: ADP :: prep
# Tesla :: PROPN :: compound
# shares :: NOUN :: pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x29e6618b348>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x29e6618b768>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x29e65e6eeb8>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x29e661cd048>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x29e6615b0c8>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x29e661541c8>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'ner', 'attribute_ruler', 'lemmatizer']

# %%
# Print each particular sentence

# %%
doc = nlp(u'In its discrete form, a hidden Markov process can be visualized as a generalization of the urn problem with replacamarement (where each item from the urn is returned to the original urn before the next step).[6] Consider this example: in a room that is not visible to an observer there is a genie. The room contains urns X1, X2, X3, ... each of which contains a known mix of balls, each ball labeled y1, y2, y3, ... . The genie chooses an urn in that room and randomly draws a ball from that urn. It then puts the ball onto a conveyor belt, where the observer can observe the sequence of the balls but not the sequence of urns from which they were drawn. The genie    has some procedure to choose urns; the choice of the urn for Amar the n-th ball depends only upon a random number and the Amarchoice of the urn for the (n − 1)-th ball. Contact 923-098-1233, 2230912301')

for sentence in doc.sents:
    print(sentence,'\n')
# Out:
# In its discrete form, a hidden Markov process can be visualized as a generalization of the urn problem with replacamarement (where each item from the urn is returned to the original urn before the next step).[6] Consider this example: in a room that is not visible to an observer there is a genie.
#
# The room contains urns X1, X2, X3, ... each of which contains a known mix of balls, each ball labeled y1, y2, y3, ... .
#
# The genie chooses an urn in that room and randomly draws a ball from that urn.
#
# It then puts the ball onto a conveyor belt, where the observer can observe the sequence of the balls but not the sequence of urns from which they were drawn.
#
# The genie    has some procedure to choose urns; the choice of the urn for Amar the n-th ball depends only upon a random number and the Amarchoice of the urn for the (n − 1)-th ball.
#
# Contact 923-098-1233, 2230912301

# %% [markdown]
# # Tokenization

# %% [markdown]
# Tokens are the basic building blocks of a Doc object - everything that helps us understand the meaning of the thext, is dereved from tokens and their relationship to one another.

# %% [markdown]
# - __Prefix__: Characters at the beginning _Eg. $ ( "_
# - __Suffix__: Characters at the end _Eg. km ) , . !"_
# - __Infix__: Characters in between _Eg. - -- / ..._
# - __Exception__: Special-case rule to split a string into several tokens to prevent a token from being split when puntuation rules are applied. _Eg let's U.S._

# %%
mystr1 = " 'We\'re goint to be great in N.Y '"
doc1 = nlp(mystr1)
mystr2 = "Here's an example - If we took away the 'when', we would have two equal clauses; ‘My Dad laughed’ and ‘I told a joke.’. It would be easier to make $5 million in Australia."
doc2 = nlp(mystr2)

# %%
for token in doc1:
    print(token.text)
# Out:
#
# '
# We
# 're
# goint
# to
# be
# greate
# in
# N.Y
# '

# %%
len(doc1), len(doc1.vocab)
# Out:
# (11, 873)

# %%
for token in doc2:
    print(token.text)
# Out:
# Here
# 's
# an
# example
# -
# If
# we
# took
# away
# the
# '
# when
# '
# ,
# we
# would
# have
# two
# equal
# clauses
# ;
# ‘
# My
# Dad
# laughed
# ’
# and
# ‘
# I
# told
# a
# joke
# .
# ’
# .
# It
# would
# be
# easier
# to
# make
# $
# 5
# million
# in
# Australia
# .

# %%
# print entitiels in doc1

for entity in doc1.ents:
    print(entity, '-', entity.label_)
# Out:
# N.Y - GPE

# %%
# print entitiels in doc2

for entity in doc2.ents:
    print(entity, '-', entity.label_, f"({str(spacy.explain(entity.label_))})")
    print('\n')
# Out:
# two - CARDINAL (Numerals that do not fall under another type)
#
#
# $5 million - MONEY (Monetary values, including unit)
#
#
# Australia - GPE (Countries, cities, states)

# %%
# Finding noun chunks

# %%
doc3 = nlp(u'Autonomous cars shift insurance liability toward manufacturers.')

for chunk in doc3.noun_chunks:
    print(chunk, chunk.label_, f"({str(spacy.explain(chunk.label_))})")
# Out:
# Autonomous cars NP (noun phrase)
# insurance liability NP (noun phrase)
# manufacturers NP (noun phrase)

# %% [markdown]
# ## Visualize Tokenization

# %%
from spacy import displacy

# %%
doc5 = nlp(u"Apple is going to build a U.K. factory for $23 million.")

# %%
# Entities
displacy.render(doc5, style='ent', jupyter=True, options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to build a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $23 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %%
# Dependencies
displacy.render(doc2, style='dep', jupyter=True, options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f3b1447311294bddb4ffa8c0a970e3ac-0" class="displacy" width="3900" height="467.0" direction="ltr" style="max-width: none; height: 467.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Here</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">example -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">If</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">took</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">away</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">the '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">when',</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">equal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">clauses; ‘</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">Dad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">laughed’</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">and ‘</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">told</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">joke.’.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">easier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">SYM</tspan>
# </text>

# %%
# It can be served as an image as well, for better visualization.
displacy.serve(doc2, style='dep')
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bf4c1da5231f42f3916e98e9345d7dc3-0" class="displacy" width="6175" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Here</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">example -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">If</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">took</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">away</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">the '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">when',</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">equal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">clauses; ‘</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">My</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Dad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">laughed’</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">and ‘</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">told</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">joke.’.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">easier</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# # Stemming

# %% [markdown]
# #### Using PorterStemmer

# %%
from nltk.stem.porter import PorterStemmer
p_stemmer = PorterStemmer()

# %%
doc5 = "She's visited her friends in Milan throughout the years."
doc5_words = doc5.split()
for word in doc5_words:
    print(word," -> ",p_stemmer.stem(word))
# Out:
# She's  ->  she'
# visited  ->  visit
# her  ->  her
# friends  ->  friend
# in  ->  in
# Milan  ->  milan
# throughout  ->  throughout
# the  ->  the
# years.  ->  years.

# %%
# another example 
words = ['run', 'ran', 'runner', 'runs', 'fairness', 'generous', 'generation', 'generously', 'generate', 'publicly', 'easily', 'fairly']
for word in words:
    print(word," -> ",p_stemmer.stem(word))
# Out:
# run  ->  run
# ran  ->  ran
# runner  ->  runner
# runs  ->  run
# fairness  ->  fair
# generous  ->  gener
# generation  ->  gener
# generously  ->  gener
# generate  ->  gener
# publicly  ->  publicli
# easily  ->  easili
# fairly  ->  fairli

# %% [markdown]
# #### Using SnowballStemmer

# %%
from nltk.stem.snowball import SnowballStemmer
s_stemmer = SnowballStemmer(language='english')

# %%
for word in words:
    print(word," -> ",s_stemmer.stem(word))
# Out:
# run  ->  run
# ran  ->  ran
# runner  ->  runner
# runs  ->  run
# fairness  ->  fair
# generous  ->  generous
# generation  ->  generat
# generously  ->  generous
# generate  ->  generat
# publicly  ->  public
# easily  ->  easili
# fairly  ->  fair

# %% [markdown]
# ## Lemmatization

# %%
doc6 = nlp(' '.join(words))

for token in doc6:
    print(f'{token.text:{12}}'+f'{token.pos_:{12}}', token.lemma_)
# Out:
# run         VERB         run
# ran         VERB         run
# runner      NOUN         runner
# runs        NOUN         run
# fairness    NOUN         fairness
# generous    ADJ          generous
# generation  NOUN         generation
# generously  ADV          generously
# generate    VERB         generate
# publicly    ADV          publicly
# easily      ADV          easily
# fairly      ADV          fairly

# %% [markdown]
# ## Stop words

# %%
# How to remove stop-words

print(len(nlp.Defaults.stop_words), nlp.Defaults.stop_words)
# Out:
# 326 {'all', 'top', 'before', 'herself', 'whose', 'never', 'per', 'would', '’s', 'down', 'former', 'becoming', 'due', 'among', 'herein', 'sometimes', 'into', '’ll', 'off', 'this', 'none', 'put', 'move', "'d", 'show', 'himself', 'somewhere', 'keep', 'alone', 'hence', 'between', 'make', 'few', 'next', '’ve', 'nobody', 'one', 'via', 'whereupon', 'also', 'quite', 'perhaps', 'for', 'so', 'ca', 'did', 'on', 'nevertheless', 'eight', 'therein', 'mostly', 'is', 'part', 'will', '’m', 'not', 'hundred', 'whom', 'might', 'in', '‘m', 'must', 'whence', 'meanwhile', 'less', 'most', 'here', 'various', 'along', 'just', 'until', 'out', 'became', 'they', 'anywhere', 'any', 'these', 'many', 'because', 'therefore', 'else', '‘s', '‘re', 'above', 'cannot', 'themselves', 'last', 'often', 'itself', 'or', 'can', 'other', 'may', 'formerly', 'that', 'unless', 'could', 'a', 'ours', 'them', 'well', 'even', 'say', 'fifty', 'third', 'besides', 'are', 'then', 'n‘t', 'nothing', 'through', 'name', 'everyone', 'four', 'across', 'being', 'she', 'thus', 'whatever', 'always', 'several', 'if', 'such', 'although', 'sometime', "n't", 'only', 'noone', '’re', 'call', 'everywhere', "'ve", 'no', 'when', 'whereby', 'someone', 'yours', 'your', 'doing', 'fifteen', 'see', 'does', 'than', 'over', 'you', 'moreover', 'however', 'rather', 'which', 'ever', 'who', 'after', 'some', 'latterly', 'from', 'its', 'thereby', 'under', 'seems', 'has', 'twenty', 'used', 'onto', 'been', 'amount', 'something', 'n’t', 'full', 'much', 'whither', 'our', 'anyhow', '‘ve', 'their', 'myself', 'during', 'without', 'about', 'namely', 'either', 'both', 'six', 'two', 'ten', 'somehow', "'s", 'mine', 'thereupon', 'were', 'each', 'we', 'beforehand', 'anyone', 'but', 'thereafter', 'own', 'side', 'empty', 'by', 'yourselves', "'ll", "'re", 'seemed', 'to', 'yourself', 'please', 'get', 'neither', 'wherever', 'was', 'us', 'forty', 'within', 'the', 'go', 'around', 'hers', 'thru', 'three', 'hereupon', 'upon', 'whole', 'seem', 'whenever', 'serious', 'afterwards', 'become', 'where', 'using', 'first', 'hereafter', 'once', '‘d', 'again', '’d', 'otherwise', 'nor', 'bottom', "'m", 'very', 'everything', 'me', 'together', 'twelve', 'sixty', 'do', 'ourselves', 'whereas', 'have', 'seeming', 'below', 'should', 'front', 'least', 'give', 'already', 'becomes', 'elsewhere', 'almost', 'latter', 'it', 're', 'nine', 'five', 'him', 'anything', 'against', 'done', 'he', 'up', 'now', 'regarding', 'her', 'be', 'how', 'while', 'whoever', 'same', 'enough', 'further', 'others', 'beyond', 'towards', 'beside', 'wherein', 'behind', 'what', 'indeed', 'made', 'those', 'with', 'yet', 'an', 'eleven', 'throughout', 'still', 'nowhere', 'and', 'of', 'take', 'am', 'whether', 'whereafter', 'though', 'every', 'had', 'except', 'really', 'at', 'his', 'since', 'amongst', 'my', 'thence', 'as', 'another', 'anyway', 'i', 'more', 'back', 'toward', 'too', 'hereby', 'why', '‘ll', 'there'}

# %%
# Check if a word is stopword
nlp.vocab['soon'].is_stop, nlp.vocab['well'].is_stop
# Out:
# (False, True)

# %%
# Add a custom word to stopwords dict
nlp.Defaults.stop_words.add('soon')
nlp.vocab['soon'].is_stop = True
nlp.vocab['soon'].is_stop
# Out:
# True

# %%
# Remove a stopword from the main dict
nlp.Defaults.stop_words.remove('well')
nlp.vocab['soon'].is_stop = False
nlp.vocab['soon'].is_stop
# Out:
# False
